# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics as sts

# %%
df_pitchfork = pd.read_csv("../data/pitchfork.csv", encoding='latin');
print(f'linhas: {df_pitchfork.shape[0]} \ncolunas: {df_pitchfork.shape[1]}')
df_pitchfork.head()
# Out:
# linhas: 99254
# colunas: 13
# C:\Users\oderl\AppData\Local\Temp\ipykernel_6124\1790152090.py:1: DtypeWarning: Columns (2,3,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pitchfork = pd.read_csv("../data/pitchfork.csv", encoding='latin');
#    reviewid                 title            artist  \
# 0   22703.0             mezzanine    massive attack
# 1   22721.0          prelapsarian          krallice
# 2   22659.0  all of them naturals      uranium club
# 3   22661.0           first songs  kleenex, liliput
# 4   22725.0             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3             0.0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9             0.0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3             0.0
# ...
